# %% [markdown]
# # Health Promotion Administration
# # & CGRD

# %%
import numpy as np
from utils import *

# %%
warnings.filterwarnings("ignore")  
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\for github'

# %% [markdown]
# # Read csv- CGRD

# %%
cgrd_2017 = pd.read_csv('data\\cgrd_2017.csv')
cgrd_2018 = pd.read_csv('data\\cgrd_2018.csv')
cgrd_2019 = pd.read_csv('data\\cgrd_2019.csv')

cgrd_2017.info()
cgrd_2018.info()
cgrd_2019.info()

cgrd_2017['year'] = 2017
cgrd_2018['year'] = 2018
cgrd_2019['year'] = 2019

cgrd_2017.tail(2)
cgrd_2018.tail(2)
cgrd_2019.tail(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268005 entries, 0 to 268004
# Columns: 114 entries, idcode to ICD_CODE
# dtypes: float64(20), int64(66), object(28)
# memory usage: 233.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271895 entries, 0 to 271894
# Columns: 114 entries, idcode to ICD_CODE
# dtypes: float64(20), int64(66), object(28)
# memory usage: 236.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274233 entries, 0 to 274232
# Columns: 114 entries, idcode to ICD_CODE
# dtypes: float64(17), int64(66), object(31)
# memory usage: 238.5+ MB
#                                           idcode breast  data_date  \
# 274231  FFFF83BC5D8EBA54B38CD37DDD2A6B1AC8311471    NaN     201912
# 274232  FFFFAFA8D6A70AF762326FF3E6EBF5C5AEC56324    NaN     201909
#
#               hosp BC_n  bc_gp        FOBT          OC  birth_year  age  ...  \
# 274231  1132070011    N    NaN         NaN  2017-08-08        1964   55  ...
# 274232  1101010012    0    6.0  2017-03-02         NaN        1962   57  ...
#
#         Colonscopy_past_date Colorectal_cancer  CLNCDXDAT CLNCDXDAT1  CAUSE  \
# 274231                   NaN                 0        NaN        NaN    NaN
# 274232                   NaN                 0        NaN        NaN    NaN
#
#         ICD  D_DATE CAUSE_CNM ICD_CODE  year
# 274231  NaN     NaN       NaN      NaN  2019
# 274232  NaN     NaN       NaN      NaN  2019
#
# [2 rows x 115 columns]

# %%
## concat 3 years
cgrd_3y = pd.concat([cgrd_2017, cgrd_2018, cgrd_2019]).reset_index(drop=True)
cgrd_3y.tail(2)
# Out:
#                                           idcode breast  data_date  \
# 814131  FFFF83BC5D8EBA54B38CD37DDD2A6B1AC8311471    NaN     201912
# 814132  FFFFAFA8D6A70AF762326FF3E6EBF5C5AEC56324    NaN     201909
#
#               hosp BC_n  bc_gp        FOBT          OC  birth_year  age  ...  \
# 814131  1132070011    N    NaN         NaN  2017-08-08        1964   55  ...
# 814132  1101010012    0    6.0  2017-03-02         NaN        1962   57  ...
#
#         Colonscopy_past_date Colorectal_cancer  CLNCDXDAT CLNCDXDAT1  CAUSE  \
# 814131                   NaN                 0        NaN        NaN    NaN
# 814132                   NaN                 0        NaN        NaN    NaN
#
#         ICD  D_DATE CAUSE_CNM ICD_CODE  year
# 814131  NaN     NaN       NaN      NaN  2019
# 814132  NaN     NaN       NaN      NaN  2019
#
# [2 rows x 115 columns]

# %% [markdown]
# # Select columns

# %%
df_3y = pd.DataFrame()
df_3y['hosp'] = (cgrd_3y.hosp).map({1101010012:'Taipei', 1132070011:'Linkou'})
df_3y['bc_gp'] = (cgrd_3y.bc_gp)
df_3y['age_gp'] = (cgrd_3y.age_gp)
df_3y['oc_gp'] = (cgrd_3y.oc_gp)
df_3y['pas_gp'] = (cgrd_3y.pas_gp)
df_3y['sex'] = (cgrd_3y.sex)
df_3y['COUNTY_'] = (cgrd_3y.COUNTY_)
# df_3y['hosp_shopping_logistic'] = (cgrd_3y.hosp_shopping_logistic)
df_3y['CCI_MI'] = (cgrd_3y.CCI_MI)
df_3y['CCI_CHF'] = (cgrd_3y.CCI_CHF)

df_3y['CCI_PVD'] = (cgrd_3y.CCI_PVD)
df_3y['CCI_CVD'] = (cgrd_3y.CCI_CVD)
df_3y['CCI_Dementia'] = (cgrd_3y.CCI_Dementia)
df_3y['CCI_COPD'] = (cgrd_3y.CCI_COPD)
df_3y['CCI_Rheumatic'] = (cgrd_3y.CCI_Rheumatic)
df_3y['CCI_Ulcer'] = (cgrd_3y.CCI_Ulcer)
df_3y['CCI_MLD'] = (cgrd_3y.CCI_MLD)
df_3y['CCI_DM_wo_chronic'] = (cgrd_3y.CCI_DM_wo_chronic)
df_3y['CCI_DM_w_chronic'] = (cgrd_3y.CCI_DM_w_chronic)
df_3y['CCI_Hemiplegia'] = (cgrd_3y.CCI_Hemiplegia)

df_3y['CCI_Renal'] = (cgrd_3y.CCI_Renal)
df_3y['CCI_Malignancy'] = (cgrd_3y.CCI_Malignancy)
df_3y['CCI_MSLD'] = (cgrd_3y.CCI_MSLD)
df_3y['CCI_Cancer'] = (cgrd_3y.CCI_Cancer)
df_3y['CCI_AIDS'] = (cgrd_3y.CCI_AIDS)
df_3y['hypertension'] = (cgrd_3y.hypertension)
df_3y['hyperlipidemia'] = (cgrd_3y.hyperlipidemia)
# df_3y['Hba1c'] = (cgrd_3y.Hba1c)
# df_3y['cholesterol'] = (cgrd_3y.cholesterol)
# df_3y['triglyceride'] = (cgrd_3y.triglyceride)

# df_3y['HDL'] = (cgrd_3y.HDL)
df_3y['SelfPay_health_examination'] = (cgrd_3y.SelfPay_health_examination)
df_3y['health_examination'] = (cgrd_3y.health_examination)
# df_3y['health_examination_diff'] = (cgrd_3y.health_examination_diff)
df_3y['Colonscopy_past'] = (cgrd_3y.Colonscopy_past)
df_3y['OPD_visit'] = (cgrd_3y.OPD_visit)

df_3y['IPD_visit'] = (cgrd_3y.IPD_visit)
df_3y['year'] = (cgrd_3y.year)
df_3y['outcome_screen'] = (cgrd_3y.outcome_screen)

df_3y.tail(2)
# Out:
#           hosp  bc_gp  age_gp  oc_gp  pas_gp sex  COUNTY_  CCI_MI  CCI_CHF  \
# 814131  Linkou    NaN       2      1     NaN   M        1       0        0
# 814132  Taipei    6.0       2      9     4.0   F        1       0        0
#
#         CCI_PVD  ...  CCI_AIDS  hypertension  hyperlipidemia  \
# 814131        0  ...         0             0               0
# 814132        0  ...         0             0               0
#
#         SelfPay_health_examination  health_examination  Colonscopy_past  \
# 814131                           0                   0                0
# 814132                           0                   0                0
#
#         OPD_visit  IPD_visit  year  outcome_screen
# 814131          2          0  2019               0
# 814132          0          0  2019               0
#
# [2 rows x 33 columns]

# %% [markdown]
# # Split on sex

# %%
## male
df_3y_M_L = df_3y[(df_3y.sex == 'M') & (df_3y.hosp == 'Linkou')].reset_index(drop=True)
del df_3y_M_L['sex']
del df_3y_M_L['bc_gp']
del df_3y_M_L['pas_gp']
del df_3y_M_L['hosp']

df_3y_M_L.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276279 entries, 0 to 276278
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   age_gp                      276279 non-null  int64
#  1   oc_gp                       276279 non-null  int64
#  2   COUNTY_                     276279 non-null  int64
#  3   CCI_MI                      276279 non-null  int64
#  4   CCI_CHF                     276279 non-null  int64
#  5   CCI_PVD                     276279 non-null  int64
#  6   CCI_CVD                     276279 non-null  int64
#  7   CCI_Dementia                276279 non-null  int64
#  8   CCI_COPD                    276279 non-null  int64
#  9   CCI_Rheumatic               276279 non-null  int64
#  10  CCI_Ulcer                   276279 non-null  int64
#  11  CCI_MLD                     276279 non-null  int64
#  12  CCI_DM_wo_chronic           276279 non-null  int64
#  13  CCI_DM_w_chronic            276279 non-null  int64
#  14  CCI_Hemiplegia              276279 non-null  int64
#  15  CCI_Renal                   276279 non-null  int64
#  16  CCI_Malignancy              276279 non-null  int64
#  17  CCI_MSLD                    276279 non-null  int64
#  18  CCI_Cancer                  276279 non-null  int64
#  19  CCI_AIDS                    276279 non-null  int64
#  20  hypertension                276279 non-null  int64
#  21  hyperlipidemia              276279 non-null  int64
#  22  SelfPay_health_examination  276279 non-null  int64
#  23  health_examination          276279 non-null  int64
#  24  Colonscopy_past             276279 non-null  int64
#  25  OPD_visit                   276279 non-null  int64
#  26  IPD_visit                   276279 non-null  int64
#  27  year                        276279 non-null  int64
#  28  outcome_screen              276279 non-null  int64
# dtypes: int64(29)
# memory usage: 61.1 MB

# %%
# ## female
# df_3y_M_L = df_3y[(df_3y.sex == 'F') & (df_3y.hosp == 'Taipei')].reset_index(drop=True)
# del df_3y_M_L['sex']
# del df_3y_M_L['hosp']

# df_3y_M_L.info()

# %% [markdown]
# # Correlation

# %%
## category
df_3y_M_Ly_catg = df_3y_M_L.iloc[:, :-4]
df_3y_M_Ly_catg['outcome_screen'] = df_3y_M_L.outcome_screen

df_3y_M_Ly_catg.corr(method='spearman') ## CCI_AIDS.value_counts() only 0 withou 1
# Out:
#                               age_gp     oc_gp   COUNTY_    CCI_MI   CCI_CHF  \
# age_gp                      1.000000  0.013877 -0.003474  0.025136  0.040736
# oc_gp                       0.013877  1.000000  0.016408 -0.005477 -0.001043
# COUNTY_                    -0.003474  0.016408  1.000000  0.005986  0.005166
# CCI_MI                      0.025136 -0.005477  0.005986  1.000000  0.204328
# CCI_CHF                     0.040736 -0.001043  0.005166  0.204328  1.000000
# CCI_PVD                     0.034429 -0.007890  0.010156  0.034299  0.056973
# CCI_CVD                     0.083385 -0.006397  0.016588  0.007477  0.034719
# CCI_Dementia                0.051778  0.003839 -0.000671  0.000141  0.006381
# CCI_COPD                    0.078092 -0.040804  0.002236  0.010974  0.057625
# CCI_Rheumatic               0.000279 -0.009490  0.004550  0.002224  0.010216
# CCI_Ulcer                   0.028439 -0.017893  0.005181  0.012907  0.022816
# CCI_MLD                    -0.018916 -0.001940  0.016042 -0.005310 -0.002922
# CCI_DM_wo_chronic           0.097435 -0.014305  0.004971  0.087683  0.092923
# CCI_DM_w_chronic            0.059438  0.003958  0.003695  0.031890  0.065328
# CCI_Hemiplegia              0.015315  0.006840  0.005071 -0.001170  0.007619
# CCI_Renal                   0.056262  0.011264  0.010283  0.042862  0.135263
# CCI_Malignancy              0.049813 -0.035533  0.004179 -0.014166 -0.011511
# CCI_MSLD                   -0.007579 -0.011080  0.002672  0.001757 -0.000788
# CCI_Cancer                  0.007194 -0.016077  0.001613 -0.004594 -0.002429
# CCI_AIDS                   -0.014713  0.002266 -0.001822 -0.002134 -0.000583
# hypertension                0.130164 -0.002076  0.010151  0.097253  0.133393
# hyperlipidemia              0.067663 -0.004030  0.008712  0.174138  0.104693
# SelfPay_health_examination -0.013650  0.015921  0.001556 -0.004770 -0.005658
# health_examination          0.112482 -0.039247  0.003570  0.030308  0.061676
# Colonscopy_past             0.053046 -0.016861  0.004771 -0.001100  0.000435
# outcome_screen              0.108479 -0.082452 -0.000865  0.007741  0.008787
#
#                              CCI_PVD   CCI_CVD  CCI_Dementia  CCI_COPD  \
# age_gp                      0.034429  0.083385      0.051778  0.078092
# oc_gp                      -0.007890 -0.006397      0.003839 -0.040804
# COUNTY_                     0.010156  0.016588     -0.000671  0.002236
# CCI_MI                      0.034299  0.007477      0.000141  0.010974
# CCI_CHF                     0.056973  0.034719      0.006381  0.057625
# CCI_PVD                     1.000000  0.046605      0.009137  0.021384
# CCI_CVD                     0.046605  1.000000      0.112475  0.017582
# CCI_Dementia                0.009137  0.112475      1.000000  0.008414
# CCI_COPD                    0.021384  0.017582      0.008414  1.000000
# CCI_Rheumatic               0.005144  0.001703      0.000338  0.021203
# CCI_Ulcer                   0.020311  0.042833      0.016606  0.057918
# CCI_MLD                     0.005704 -0.012783      0.001328  0.020774
# CCI_DM_wo_chronic           0.056788  0.158957      0.033064  0.035556
# CCI_DM_w_chronic            0.061714  0.046806      0.016367  0.018025
# CCI_Hemiplegia              0.015962  0.206988      0.033246  0.004441
# CCI_Renal                   0.090726  0.044033      0.015048  0.028335
# CCI_Malignancy             -0.007694  0.009767     -0.002504  0.032972
# CCI_MSLD                   -0.001159  0.000541     -0.001107  0.003930
# CCI_Cancer                 -0.000627 -0.001226     -0.001285  0.024759
# CCI_AIDS                   -0.002765 -0.000602     -0.002057  0.007942
# hypertension                0.132717  0.302783      0.051607  0.078569
# hyperlipidemia              0.048985  0.207671      0.027389  0.044897
# SelfPay_health_examination -0.002888 -0.011442     -0.005247  0.001472
# health_examination          0.048814  0.085850      0.041961  0.107852
# Colonscopy_past             0.008681 -0.000366      0.007219  0.034651
# outcome_screen              0.012233  0.009481      0.002162  0.048747
#
#                             CCI_Rheumatic  ...  CCI_Malignancy  CCI_MSLD  \
# age_gp                           0.000279  ...        0.049813 -0.007579
# oc_gp                           -0.009490  ...       -0.035533 -0.011080
# COUNTY_                          0.004550  ...        0.004179  0.002672
# CCI_MI                           0.002224  ...       -0.014166  0.001757
# CCI_CHF                          0.010216  ...       -0.011511 -0.000788
# CCI_PVD                          0.005144  ...       -0.007694 -0.001159
# CCI_CVD                          0.001703  ...        0.009767  0.000541
# CCI_Dementia                     0.000338  ...       -0.002504 -0.001107
# CCI_COPD                         0.021203  ...        0.032972  0.003930
# CCI_Rheumatic                    1.000000  ...       -0.006318 -0.001915
# CCI_Ulcer                        0.035409  ...        0.053175  0.068312
# CCI_MLD                          0.007548  ...        0.118442  0.123097
# CCI_DM_wo_chronic                0.007375  ...        0.028142  0.015292
# CCI_DM_w_chronic                -0.001227  ...       -0.001736  0.004172
# CCI_Hemiplegia                  -0.002640  ...       -0.008966 -0.001100
# CCI_Renal                        0.008188  ...        0.024863  0.009747
# CCI_Malignancy                  -0.006318  ...        1.000000  0.044323
# CCI_MSLD                        -0.001915  ...        0.044323  1.000000
# CCI_Cancer                      -0.002277  ...        0.233549  0.007308
# CCI_AIDS                         0.001866  ...       -0.003800 -0.001300
# hypertension                     0.015611  ...        0.034709  0.007034
# hyperlipidemia                   0.005359  ...        0.007080 -0.003546
# SelfPay_health_examination      -0.001174  ...       -0.012220  0.001080
# health_examination               0.043213  ...        0.156168  0.023937
# Colonscopy_past                  0.005570  ...        0.030894  0.005671
# outcome_screen                   0.013964  ...        0.015309 -0.003320
#
#                             CCI_Cancer  CCI_AIDS  hypertension  \
# age_gp                        0.007194 -0.014713      0.130164
# oc_gp                        -0.016077  0.002266     -0.002076
# COUNTY_                       0.001613 -0.001822      0.010151
# CCI_MI                       -0.004594 -0.002134      0.097253
# CCI_CHF                      -0.002429 -0.000583      0.133393
# CCI_PVD                      -0.000627 -0.002765      0.132717
# CCI_CVD                      -0.001226 -0.000602      0.302783
# CCI_Dementia                 -0.001285 -0.002057      0.051607
# CCI_COPD                      0.024759  0.007942      0.078569
# CCI_Rheumatic                -0.002277  0.001866      0.015611
# CCI_Ulcer                     0.019699  0.009296      0.096085
# CCI_MLD                       0.022882  0.005036      0.068814
# CCI_DM_wo_chronic             0.013231  0.004507      0.399007
# CCI_DM_w_chronic              0.002100 -0.005083      0.219595
# CCI_Hemiplegia                0.000202  0.001492      0.073942
# CCI_Renal                     0.003414 -0.001377      0.229128
# CCI_Malignancy                0.233549 -0.003800      0.034709
# CCI_MSLD                      0.007308 -0.001300      0.007034
# CCI_Cancer                    1.000000 -0.001950      0.016965
# CCI_AIDS                     -0.001950  1.000000      0.005330
# hypertension                  0.016965  0.005330      1.000000
# hyperlipidemia               -0.002955  0.018208      0.460906
# SelfPay_health_examination   -0.004976 -0.002061     -0.001126
# health_examination            0.084748  0.000993      0.177775
# Colonscopy_past               0.002821 -0.002956      0.048353
# outcome_screen               -0.004558 -0.002605      0.067312
#
#                             hyperlipidemia  SelfPay_health_examination  \
# age_gp                            0.067663                   -0.013650
# oc_gp                            -0.004030                    0.015921
# COUNTY_                           0.008712                    0.001556
# CCI_MI                            0.174138                   -0.004770
# CCI_CHF                           0.104693                   -0.005658
# CCI_PVD                           0.048985                   -0.002888
# CCI_CVD                           0.207671                   -0.011442
# CCI_Dementia                      0.027389                   -0.005247
# CCI_COPD                          0.044897                    0.001472
# CCI_Rheumatic                     0.005359                   -0.001174
# CCI_Ulcer                         0.096677                    0.016505
# CCI_MLD                           0.115401                    0.008100
# CCI_DM_wo_chronic                 0.410008                   -0.007887
# CCI_DM_w_chronic                  0.229664                   -0.004280
# CCI_Hemiplegia                    0.037570                   -0.003145
# CCI_Renal                         0.100735                   -0.007985
# CCI_Malignancy                    0.007080                   -0.012220
# CCI_MSLD                         -0.003546                    0.001080
# CCI_Cancer                       -0.002955                   -0.004976
# CCI_AIDS                          0.018208                   -0.002061
# hypertension                      0.460906                   -0.001126
# hyperlipidemia                    1.000000                    0.013030
# SelfPay_health_examination        0.013030                    1.000000
# health_examination                0.132188                    0.005806
# Colonscopy_past                   0.066744                    0.007527
# outcome_screen                    0.071300                   -0.021613
#
#                             health_examination  Colonscopy_past  \
# age_gp                                0.112482         0.053046
# oc_gp                                -0.039247        -0.016861
# COUNTY_                               0.003570         0.004771
# CCI_MI                                0.030308        -0.001100
# CCI_CHF                               0.061676         0.000435
# CCI_PVD                               0.048814         0.008681
# CCI_CVD                               0.085850        -0.000366
# CCI_Dementia                          0.041961         0.007219
# CCI_COPD                              0.107852         0.034651
# CCI_Rheumatic                         0.043213         0.005570
# CCI_Ulcer                             0.108120         0.121734
# CCI_MLD                               0.099440         0.102163
# CCI_DM_wo_chronic                     0.144065         0.028489
# CCI_DM_w_chronic                      0.118927         0.017888
# CCI_Hemiplegia                        0.043626        -0.003854
# CCI_Renal                             0.166213         0.021459
# CCI_Malignancy                        0.156168         0.030894
# CCI_MSLD                              0.023937         0.005671
# CCI_Cancer                            0.084748         0.002821
# CCI_AIDS                              0.000993        -0.002956
# hypertension                          0.177775         0.048353
# hyperlipidemia                        0.132188         0.066744
# SelfPay_health_examination            0.005806         0.007527
# health_examination                    1.000000         0.064466
# Colonscopy_past                       0.064466         1.000000
# outcome_screen                        0.090705         0.035200
#
#                             outcome_screen
# age_gp                            0.108479
# oc_gp                            -0.082452
# COUNTY_                          -0.000865
# CCI_MI                            0.007741
# CCI_CHF                           0.008787
# CCI_PVD                           0.012233
# CCI_CVD                           0.009481
# CCI_Dementia                      0.002162
# CCI_COPD                          0.048747
# CCI_Rheumatic                     0.013964
# CCI_Ulcer                         0.039747
# CCI_MLD                           0.066589
# CCI_DM_wo_chronic                 0.049194
# CCI_DM_w_chronic                  0.029457
# CCI_Hemiplegia                   -0.003376
# CCI_Renal                         0.015916
# CCI_Malignancy                    0.015309
# CCI_MSLD                         -0.003320
# CCI_Cancer                       -0.004558
# CCI_AIDS                         -0.002605
# hypertension                      0.067312
# hyperlipidemia                    0.071300
# SelfPay_health_examination       -0.021613
# health_examination                0.090705
# Colonscopy_past                   0.035200
# outcome_screen                    1.000000
#
# [26 rows x 26 columns]

# %%
## numeric 
df_3y_M_Ly_num = df_3y_M_L.iloc[:, -4:-2]
df_3y_M_Ly_num['outcome_screen'] = df_3y_M_L.outcome_screen
df_3y_M_Ly_num.corr()
# Out:
#                 OPD_visit  IPD_visit  outcome_screen
# OPD_visit        1.000000   0.396521        0.093069
# IPD_visit        0.396521   1.000000        0.002512
# outcome_screen   0.093069   0.002512        1.000000

# %% [markdown]
# # Split to training/ valid/ test

# %%
X_train = df_3y_M_L[df_3y_M_L.year == 2017].iloc[:, :-2]
y_train = df_3y_M_L[df_3y_M_L.year == 2017].outcome_screen

X_valid = df_3y_M_L[df_3y_M_L.year == 2018].iloc[:, :-2]
y_valid = df_3y_M_L[df_3y_M_L.year == 2018].outcome_screen

X_test = df_3y_M_L[df_3y_M_L.year == 2019].iloc[:, :-2]
y_test = df_3y_M_L[df_3y_M_L.year == 2019].outcome_screen

# %% [markdown]
# # Model_XGBoost Classifier

# %%
start_time = time.time()

xgb = XGBClassifier()
cv = cross_val_score(xgb,X_train,y_train,cv=5)
print(xgboost.__version__)
print(cv)
print('XGBClassifier:', cv.mean())
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [15:21:53] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:21:54] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:21:54] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:21:55] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:21:56] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 1.4.2
# [0.73907203 0.73877757 0.73844173 0.73944923 0.73698645]
# XGBClassifier: 0.7385454038729179
# --- 4.237352609634399 seconds ---

# %% [markdown]
# # Training

# %%
train = confusio_matrix(xgb, X_train, y_train)
plot_roc_curve(xgb, X_train, y_train)

train = train.rename(index={0: "M_L_HPA+CGRD_train"})
print('--------------- True/False Pos/Neg ---------------')
print(train, '\n')

train_imp = get_impotances(xgb, X_train, y_train)
train_imp.columns = ['M_L_HPA+CGRD_column', 'M_L_train_impor']

# train_imp
# Out:
# [15:21:57] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# --------------- True/False Pos/Neg ---------------
#                    True Neg False Pos False Neg True Pos    AUC
# M_L_HPA+CGRD_train    65624       608     21432     1667  0.531
#
# [15:21:58] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# # Validation

# %%
valid = confusio_matrix(xgb, X_valid, y_valid)
plot_roc_curve(xgb, X_valid, y_valid)

valid = valid.rename(index={0: "M_L_HPA+CGRD_valid"})
print('--------------- True/False Pos/Neg ---------------')
print(valid, '\n')

valid_imp = get_impotances(xgb, X_valid, y_valid)
valid_imp.columns = ['M_L_HPA+CGRD_column', 'M_L_valid_impor']
# valid_imp
# Out:
# [15:22:00] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# --------------- True/False Pos/Neg ---------------
#                    True Neg False Pos False Neg True Pos   AUC
# M_L_HPA+CGRD_valid    66957      1111     21921     2341  0.54
#
# [15:22:01] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# # Test

# %%
test = confusio_matrix(xgb, X_test, y_test)
plot_roc_curve(xgb, X_test, y_test)

test = test.rename(index={0: "M_L_HPA+CGRD_test"})
print('--------------- True/False Pos/Neg ---------------')
print(test, '\n')

test_imp = get_impotances(xgb, X_test, y_test)
test_imp.columns = ['M_L_HPA+CGRD_column', 'M_L_test_impor']
# test_imp
# Out:
# [15:22:02] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# --------------- True/False Pos/Neg ---------------
#                   True Neg False Pos False Neg True Pos    AUC
# M_L_HPA+CGRD_test    71039       430     21852     1297  0.525
#
# [15:22:04] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# # Result

# %%
print('--- Male_Linkou HPA+CGRD result---')
result = pd.concat([train, valid, test])
result
# Out:
# --- Male_Linkou HPA+CGRD result---
#                    True Neg False Pos False Neg True Pos    AUC
# M_L_HPA+CGRD_train    65624       608     21432     1667  0.531
# M_L_HPA+CGRD_valid    66957      1111     21921     2341   0.54
# M_L_HPA+CGRD_test     71039       430     21852     1297  0.525

# %%
result1 = train_imp.merge(valid_imp, left_on='M_L_HPA+CGRD_column', right_on='M_L_HPA+CGRD_column')
result1 = result1.merge(test_imp, left_on='M_L_HPA+CGRD_column', right_on='M_L_HPA+CGRD_column')
result1
# Out:
#            M_L_HPA+CGRD_column  M_L_train_impor  M_L_valid_impor  \
# 0                        oc_gp         0.149154         0.119759
# 1           health_examination         0.078293         0.082111
# 2                       age_gp         0.074136         0.079295
# 3                    OPD_visit         0.055179         0.052882
# 4                      CCI_MLD         0.049328         0.047415
# 5   SelfPay_health_examination         0.044908         0.054894
# 6                     CCI_COPD         0.033483         0.029496
# 7               hyperlipidemia         0.032854         0.027275
# 8                    CCI_Renal         0.032200         0.031463
# 9                      CCI_CVD         0.030789         0.042009
# 10              CCI_Malignancy         0.030563         0.076055
# 11                     COUNTY_         0.029193         0.023828
# 12             Colonscopy_past         0.028843         0.030953
# 13                     CCI_PVD         0.026681         0.023498
# 14                      CCI_MI         0.026467         0.028262
# 15                   IPD_visit         0.026091         0.024645
# 16                     CCI_CHF         0.025912         0.027311
# 17                  CCI_Cancer         0.025847         0.015134
# 18            CCI_DM_w_chronic         0.024913         0.027610
# 19               CCI_Rheumatic         0.024683         0.015507
# 20                CCI_Dementia         0.024571         0.017895
# 21                   CCI_Ulcer         0.024381         0.022050
# 22           CCI_DM_wo_chronic         0.023885         0.021455
# 23                hypertension         0.022526         0.021143
# 24              CCI_Hemiplegia         0.020755         0.021074
# 25                    CCI_AIDS         0.018278         0.015435
# 26                    CCI_MSLD         0.016088         0.021547
#
#     M_L_test_impor
# 0         0.110974
# 1         0.070393
# 2         0.076110
# 3         0.061234
# 4         0.046430
# 5         0.054490
# 6         0.026893
# 7         0.032104
# 8         0.031456
# 9         0.045466
# 10        0.033474
# 11        0.029387
# 12        0.024079
# 13        0.022139
# 14        0.024543
# 15        0.028946
# 16        0.029420
# 17        0.027200
# 18        0.029734
# 19        0.026701
# 20        0.036120
# 21        0.023433
# 22        0.024600
# 23        0.022153
# 24        0.021069
# 25        0.023164
# 26        0.018289
