# %% [markdown]
# # Health Promotion Administration
# # & CGRD

# %%
import numpy as np
from utils import *

# %%
warnings.filterwarnings("ignore")  
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\for github'

# %% [markdown]
# # Read csv- CGRD

# %%
cgrd_2017 = pd.read_csv('data\\cgrd_2017.csv')
cgrd_2018 = pd.read_csv('data\\cgrd_2018.csv')
cgrd_2019 = pd.read_csv('data\\cgrd_2019.csv')

cgrd_2017.info()
cgrd_2018.info()
cgrd_2019.info()

cgrd_2017['year'] = 2017
cgrd_2018['year'] = 2018
cgrd_2019['year'] = 2019

cgrd_2017.tail(2)
cgrd_2018.tail(2)
cgrd_2019.tail(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268005 entries, 0 to 268004
# Columns: 114 entries, idcode to ICD_CODE
# dtypes: float64(20), int64(66), object(28)
# memory usage: 233.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271895 entries, 0 to 271894
# Columns: 114 entries, idcode to ICD_CODE
# dtypes: float64(20), int64(66), object(28)
# memory usage: 236.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274233 entries, 0 to 274232
# Columns: 114 entries, idcode to ICD_CODE
# dtypes: float64(17), int64(66), object(31)
# memory usage: 238.5+ MB
#                                           idcode breast  data_date  \
# 274231  FFFF83BC5D8EBA54B38CD37DDD2A6B1AC8311471    NaN     201912
# 274232  FFFFAFA8D6A70AF762326FF3E6EBF5C5AEC56324    NaN     201909
#
#               hosp BC_n  bc_gp        FOBT          OC  birth_year  age  ...  \
# 274231  1132070011    N    NaN         NaN  2017-08-08        1964   55  ...
# 274232  1101010012    0    6.0  2017-03-02         NaN        1962   57  ...
#
#         Colonscopy_past_date Colorectal_cancer  CLNCDXDAT CLNCDXDAT1  CAUSE  \
# 274231                   NaN                 0        NaN        NaN    NaN
# 274232                   NaN                 0        NaN        NaN    NaN
#
#         ICD  D_DATE CAUSE_CNM ICD_CODE  year
# 274231  NaN     NaN       NaN      NaN  2019
# 274232  NaN     NaN       NaN      NaN  2019
#
# [2 rows x 115 columns]

# %%
## concat 3 years
cgrd_3y = pd.concat([cgrd_2017, cgrd_2018, cgrd_2019]).reset_index(drop=True)
cgrd_3y.tail(2)
# Out:
#                                           idcode breast  data_date  \
# 814131  FFFF83BC5D8EBA54B38CD37DDD2A6B1AC8311471    NaN     201912
# 814132  FFFFAFA8D6A70AF762326FF3E6EBF5C5AEC56324    NaN     201909
#
#               hosp BC_n  bc_gp        FOBT          OC  birth_year  age  ...  \
# 814131  1132070011    N    NaN         NaN  2017-08-08        1964   55  ...
# 814132  1101010012    0    6.0  2017-03-02         NaN        1962   57  ...
#
#         Colonscopy_past_date Colorectal_cancer  CLNCDXDAT CLNCDXDAT1  CAUSE  \
# 814131                   NaN                 0        NaN        NaN    NaN
# 814132                   NaN                 0        NaN        NaN    NaN
#
#         ICD  D_DATE CAUSE_CNM ICD_CODE  year
# 814131  NaN     NaN       NaN      NaN  2019
# 814132  NaN     NaN       NaN      NaN  2019
#
# [2 rows x 115 columns]

# %% [markdown]
# # Select columns

# %%
df_3y = pd.DataFrame()
df_3y['hosp'] = (cgrd_3y.hosp).map({1101010012:'Taipei', 1132070011:'Linkou'})
df_3y['bc_gp'] = (cgrd_3y.bc_gp)
df_3y['age_gp'] = (cgrd_3y.age_gp)
df_3y['oc_gp'] = (cgrd_3y.oc_gp)
df_3y['pas_gp'] = (cgrd_3y.pas_gp)
df_3y['sex'] = (cgrd_3y.sex)
df_3y['COUNTY_'] = (cgrd_3y.COUNTY_)
# df_3y['hosp_shopping_logistic'] = (cgrd_3y.hosp_shopping_logistic)
df_3y['CCI_MI'] = (cgrd_3y.CCI_MI)
df_3y['CCI_CHF'] = (cgrd_3y.CCI_CHF)

df_3y['CCI_PVD'] = (cgrd_3y.CCI_PVD)
df_3y['CCI_CVD'] = (cgrd_3y.CCI_CVD)
df_3y['CCI_Dementia'] = (cgrd_3y.CCI_Dementia)
df_3y['CCI_COPD'] = (cgrd_3y.CCI_COPD)
df_3y['CCI_Rheumatic'] = (cgrd_3y.CCI_Rheumatic)
df_3y['CCI_Ulcer'] = (cgrd_3y.CCI_Ulcer)
df_3y['CCI_MLD'] = (cgrd_3y.CCI_MLD)
df_3y['CCI_DM_wo_chronic'] = (cgrd_3y.CCI_DM_wo_chronic)
df_3y['CCI_DM_w_chronic'] = (cgrd_3y.CCI_DM_w_chronic)
df_3y['CCI_Hemiplegia'] = (cgrd_3y.CCI_Hemiplegia)

df_3y['CCI_Renal'] = (cgrd_3y.CCI_Renal)
df_3y['CCI_Malignancy'] = (cgrd_3y.CCI_Malignancy)
df_3y['CCI_MSLD'] = (cgrd_3y.CCI_MSLD)
df_3y['CCI_Cancer'] = (cgrd_3y.CCI_Cancer)
df_3y['CCI_AIDS'] = (cgrd_3y.CCI_AIDS)
df_3y['hypertension'] = (cgrd_3y.hypertension)
df_3y['hyperlipidemia'] = (cgrd_3y.hyperlipidemia)
# df_3y['Hba1c'] = (cgrd_3y.Hba1c)
# df_3y['cholesterol'] = (cgrd_3y.cholesterol)
# df_3y['triglyceride'] = (cgrd_3y.triglyceride)

# df_3y['HDL'] = (cgrd_3y.HDL)
df_3y['SelfPay_health_examination'] = (cgrd_3y.SelfPay_health_examination)
df_3y['health_examination'] = (cgrd_3y.health_examination)
# df_3y['health_examination_diff'] = (cgrd_3y.health_examination_diff)
df_3y['Colonscopy_past'] = (cgrd_3y.Colonscopy_past)
df_3y['OPD_visit'] = (cgrd_3y.OPD_visit)

df_3y['IPD_visit'] = (cgrd_3y.IPD_visit)
df_3y['year'] = (cgrd_3y.year)
df_3y['outcome_screen'] = (cgrd_3y.outcome_screen)

df_3y.tail(2)
# Out:
#           hosp  bc_gp  age_gp  oc_gp  pas_gp sex  COUNTY_  CCI_MI  CCI_CHF  \
# 814131  Linkou    NaN       2      1     NaN   M        1       0        0
# 814132  Taipei    6.0       2      9     4.0   F        1       0        0
#
#         CCI_PVD  ...  CCI_AIDS  hypertension  hyperlipidemia  \
# 814131        0  ...         0             0               0
# 814132        0  ...         0             0               0
#
#         SelfPay_health_examination  health_examination  Colonscopy_past  \
# 814131                           0                   0                0
# 814132                           0                   0                0
#
#         OPD_visit  IPD_visit  year  outcome_screen
# 814131          2          0  2019               0
# 814132          0          0  2019               0
#
# [2 rows x 33 columns]

# %% [markdown]
# # Split on sex

# %%
## male
df_3y_M_T = df_3y[(df_3y.sex == 'M') & (df_3y.hosp == 'Taipei')].reset_index(drop=True)
del df_3y_M_T['sex']
del df_3y_M_T['bc_gp']
del df_3y_M_T['pas_gp']
del df_3y_M_T['hosp']

df_3y_M_T.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81548 entries, 0 to 81547
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age_gp                      81548 non-null  int64
#  1   oc_gp                       81548 non-null  int64
#  2   COUNTY_                     81548 non-null  int64
#  3   CCI_MI                      81548 non-null  int64
#  4   CCI_CHF                     81548 non-null  int64
#  5   CCI_PVD                     81548 non-null  int64
#  6   CCI_CVD                     81548 non-null  int64
#  7   CCI_Dementia                81548 non-null  int64
#  8   CCI_COPD                    81548 non-null  int64
#  9   CCI_Rheumatic               81548 non-null  int64
#  10  CCI_Ulcer                   81548 non-null  int64
#  11  CCI_MLD                     81548 non-null  int64
#  12  CCI_DM_wo_chronic           81548 non-null  int64
#  13  CCI_DM_w_chronic            81548 non-null  int64
#  14  CCI_Hemiplegia              81548 non-null  int64
#  15  CCI_Renal                   81548 non-null  int64
#  16  CCI_Malignancy              81548 non-null  int64
#  17  CCI_MSLD                    81548 non-null  int64
#  18  CCI_Cancer                  81548 non-null  int64
#  19  CCI_AIDS                    81548 non-null  int64
#  20  hypertension                81548 non-null  int64
#  21  hyperlipidemia              81548 non-null  int64
#  22  SelfPay_health_examination  81548 non-null  int64
#  23  health_examination          81548 non-null  int64
#  24  Colonscopy_past             81548 non-null  int64
#  25  OPD_visit                   81548 non-null  int64
#  26  IPD_visit                   81548 non-null  int64
#  27  year                        81548 non-null  int64
#  28  outcome_screen              81548 non-null  int64
# dtypes: int64(29)
# memory usage: 18.0 MB

# %%
# ## female
# df_3y_M_T = df_3y[(df_3y.sex == 'F') & (df_3y.hosp == 'Taipei')].reset_index(drop=True)
# del df_3y_M_T['sex']
# del df_3y_M_T['hosp']

# df_3y_M_T.info()

# %% [markdown]
# # Correlation

# %%
## category
df_3y_M_Ty_catg = df_3y_M_T.iloc[:, :-4]
df_3y_M_Ty_catg['outcome_screen'] = df_3y_M_T.outcome_screen

df_3y_M_Ty_catg.corr(method='spearman') ## CCI_AIDS.value_counts() only 0 withou 1
# Out:
#                               age_gp     oc_gp   COUNTY_    CCI_MI   CCI_CHF  \
# age_gp                      1.000000  0.012546 -0.003472  0.019406  0.032876
# oc_gp                       0.012546  1.000000  0.029411 -0.008844 -0.010802
# COUNTY_                    -0.003472  0.029411  1.000000  0.004358  0.003518
# CCI_MI                      0.019406 -0.008844  0.004358  1.000000  0.213959
# CCI_CHF                     0.032876 -0.010802  0.003518  0.213959  1.000000
# CCI_PVD                     0.023577 -0.004942  0.004918  0.055515  0.019495
# CCI_CVD                     0.069811 -0.006259  0.005756  0.011540  0.020777
# CCI_Dementia                0.041399 -0.000688 -0.001657 -0.004650  0.000721
# CCI_COPD                    0.060191 -0.021271  0.004712  0.009125  0.044175
# CCI_Rheumatic               0.008395 -0.009748  0.004472 -0.004583 -0.004563
# CCI_Ulcer                   0.022841 -0.022579  0.018809  0.016651  0.016877
# CCI_MLD                    -0.009991  0.002945  0.033935 -0.003054  0.008071
# CCI_DM_wo_chronic           0.081780 -0.011548  0.024560  0.043787  0.066125
# CCI_DM_w_chronic            0.053073 -0.014220  0.012092  0.018565  0.042595
# CCI_Hemiplegia              0.009437 -0.004298 -0.001492  0.013314  0.005192
# CCI_Renal                   0.048218 -0.001980  0.001610  0.023181  0.066946
# CCI_Malignancy              0.039938 -0.017544 -0.017274 -0.003376  0.017263
# CCI_MSLD                    0.005583  0.003349  0.002417 -0.002299 -0.002289
# CCI_Cancer                  0.005829 -0.002486 -0.011798 -0.001070 -0.001065
# CCI_AIDS                   -0.004372  0.002771  0.003258 -0.001293 -0.001288
# hypertension                0.107712  0.000080  0.029980  0.075930  0.096826
# hyperlipidemia              0.062510  0.002205  0.040213  0.137359  0.090988
# SelfPay_health_examination -0.015488  0.005602 -0.022139 -0.004621 -0.004601
# health_examination          0.110829 -0.037297  0.015316  0.022996  0.042190
# Colonscopy_past             0.026770 -0.013316  0.016524 -0.001074  0.002193
# outcome_screen              0.119103 -0.077423  0.007205 -0.001644  0.002193
#
#                              CCI_PVD   CCI_CVD  CCI_Dementia  CCI_COPD  \
# age_gp                      0.023577  0.069811      0.041399  0.060191
# oc_gp                      -0.004942 -0.006259     -0.000688 -0.021271
# COUNTY_                     0.004918  0.005756     -0.001657  0.004712
# CCI_MI                      0.055515  0.011540     -0.004650  0.009125
# CCI_CHF                     0.019495  0.020777      0.000721  0.044175
# CCI_PVD                     1.000000  0.045372      0.013804  0.014859
# CCI_CVD                     0.045372  1.000000      0.090647  0.012820
# CCI_Dementia                0.013804  0.090647      1.000000  0.010068
# CCI_COPD                    0.014859  0.012820      0.010068  1.000000
# CCI_Rheumatic               0.028199 -0.001762      0.005337  0.010453
# CCI_Ulcer                   0.036042  0.051245      0.020484  0.052802
# CCI_MLD                     0.021229 -0.003954      0.000989  0.024045
# CCI_DM_wo_chronic           0.070156  0.097529      0.016196  0.029891
# CCI_DM_w_chronic            0.075494  0.034622      0.004056  0.019521
# CCI_Hemiplegia              0.013658  0.143829      0.016873  0.011014
# CCI_Renal                   0.063844  0.041438      0.008061  0.034760
# CCI_Malignancy             -0.000805  0.001421     -0.000434  0.023729
# CCI_MSLD                   -0.001758 -0.004025      0.006774  0.002085
# CCI_Cancer                 -0.000818 -0.001873     -0.000693 -0.001896
# CCI_AIDS                   -0.000989 -0.002265     -0.000838 -0.002292
# hypertension                0.086390  0.228986      0.040384  0.059655
# hyperlipidemia              0.069845  0.140260      0.013523  0.036526
# SelfPay_health_examination -0.000042  0.001225     -0.002995 -0.002051
# health_examination          0.051168  0.069522      0.033641  0.086581
# Colonscopy_past             0.014110  0.003556      0.012612  0.025170
# outcome_screen              0.007367  0.005838      0.010228  0.029656
#
#                             CCI_Rheumatic  ...  CCI_Malignancy  CCI_MSLD  \
# age_gp                           0.008395  ...        0.039938  0.005583
# oc_gp                           -0.009748  ...       -0.017544  0.003349
# COUNTY_                          0.004472  ...       -0.017274  0.002417
# CCI_MI                          -0.004583  ...       -0.003376 -0.002299
# CCI_CHF                         -0.004563  ...        0.017263 -0.002289
# CCI_PVD                          0.028199  ...       -0.000805 -0.001758
# CCI_CVD                         -0.001762  ...        0.001421 -0.004025
# CCI_Dementia                     0.005337  ...       -0.000434  0.006774
# CCI_COPD                         0.010453  ...        0.023729  0.002085
# CCI_Rheumatic                    1.000000  ...       -0.002253 -0.001468
# CCI_Ulcer                        0.052558  ...        0.038340  0.034470
# CCI_MLD                          0.009215  ...        0.084624  0.067625
# CCI_DM_wo_chronic                0.001108  ...        0.015632  0.016617
# CCI_DM_w_chronic                 0.002652  ...        0.004839 -0.003735
# CCI_Hemiplegia                   0.010806  ...       -0.004124 -0.000970
# CCI_Renal                        0.006656  ...        0.023208  0.010181
# CCI_Malignancy                  -0.002253  ...        1.000000  0.052457
# CCI_MSLD                        -0.001468  ...        0.052457  1.000000
# CCI_Cancer                      -0.000683  ...        0.100877 -0.000343
# CCI_AIDS                        -0.000826  ...        0.005292 -0.000414
# hypertension                     0.008319  ...        0.021854  0.004666
# hyperlipidemia                   0.006802  ...        0.024190  0.003602
# SelfPay_health_examination       0.005407  ...       -0.000359 -0.001480
# health_examination               0.033277  ...        0.065482  0.011505
# Colonscopy_past                  0.001693  ...        0.034002  0.010321
# outcome_screen                   0.005405  ...        0.019412  0.003887
#
#                             CCI_Cancer  CCI_AIDS  hypertension  \
# age_gp                        0.005829 -0.004372      0.107712
# oc_gp                        -0.002486  0.002771      0.000080
# COUNTY_                      -0.011798  0.003258      0.029980
# CCI_MI                       -0.001070 -0.001293      0.075930
# CCI_CHF                      -0.001065 -0.001288      0.096826
# CCI_PVD                      -0.000818 -0.000989      0.086390
# CCI_CVD                      -0.001873 -0.002265      0.228986
# CCI_Dementia                 -0.000693 -0.000838      0.040384
# CCI_COPD                     -0.001896 -0.002292      0.059655
# CCI_Rheumatic                -0.000683 -0.000826      0.008319
# CCI_Ulcer                     0.002127  0.004708      0.088559
# CCI_MLD                       0.018872  0.011315      0.104155
# CCI_DM_wo_chronic             0.006154  0.003568      0.373391
# CCI_DM_w_chronic             -0.001738 -0.002101      0.188074
# CCI_Hemiplegia               -0.000451 -0.000546      0.042714
# CCI_Renal                     0.013136 -0.002037      0.191974
# CCI_Malignancy                0.100877  0.005292      0.021854
# CCI_MSLD                     -0.000343 -0.000414      0.004666
# CCI_Cancer                    1.000000 -0.000193      0.002664
# CCI_AIDS                     -0.000193  1.000000      0.000143
# hypertension                  0.002664  0.000143      1.000000
# hyperlipidemia                0.000054  0.013654      0.492699
# SelfPay_health_examination   -0.000689 -0.000833      0.006617
# health_examination            0.019825 -0.000458      0.152302
# Colonscopy_past              -0.003185 -0.000462      0.045278
# outcome_screen               -0.002519 -0.001016      0.060602
#
#                             hyperlipidemia  SelfPay_health_examination  \
# age_gp                            0.062510                   -0.015488
# oc_gp                             0.002205                    0.005602
# COUNTY_                           0.040213                   -0.022139
# CCI_MI                            0.137359                   -0.004621
# CCI_CHF                           0.090988                   -0.004601
# CCI_PVD                           0.069845                   -0.000042
# CCI_CVD                           0.140260                    0.001225
# CCI_Dementia                      0.013523                   -0.002995
# CCI_COPD                          0.036526                   -0.002051
# CCI_Rheumatic                     0.006802                    0.005407
# CCI_Ulcer                         0.121567                    0.014072
# CCI_MLD                           0.211161                    0.005030
# CCI_DM_wo_chronic                 0.453336                   -0.001541
# CCI_DM_w_chronic                  0.216814                   -0.002502
# CCI_Hemiplegia                    0.017366                   -0.001950
# CCI_Renal                         0.098372                   -0.000399
# CCI_Malignancy                    0.024190                   -0.000359
# CCI_MSLD                          0.003602                   -0.001480
# CCI_Cancer                        0.000054                   -0.000689
# CCI_AIDS                          0.013654                   -0.000833
# hypertension                      0.492699                    0.006617
# hyperlipidemia                    1.000000                    0.013265
# SelfPay_health_examination        0.013265                    1.000000
# health_examination                0.139036                   -0.004093
# Colonscopy_past                   0.062782                    0.010008
# outcome_screen                    0.067923                   -0.013649
#
#                             health_examination  Colonscopy_past  \
# age_gp                                0.110829         0.026770
# oc_gp                                -0.037297        -0.013316
# COUNTY_                               0.015316         0.016524
# CCI_MI                                0.022996        -0.001074
# CCI_CHF                               0.042190         0.002193
# CCI_PVD                               0.051168         0.014110
# CCI_CVD                               0.069522         0.003556
# CCI_Dementia                          0.033641         0.012612
# CCI_COPD                              0.086581         0.025170
# CCI_Rheumatic                         0.033277         0.001693
# CCI_Ulcer                             0.113046         0.122394
# CCI_MLD                               0.091529         0.103633
# CCI_DM_wo_chronic                     0.126018         0.026352
# CCI_DM_w_chronic                      0.077432         0.019654
# CCI_Hemiplegia                        0.024851        -0.000318
# CCI_Renal                             0.108356         0.018037
# CCI_Malignancy                        0.065482         0.034002
# CCI_MSLD                              0.011505         0.010321
# CCI_Cancer                            0.019825        -0.003185
# CCI_AIDS                             -0.000458        -0.000462
# hypertension                          0.152302         0.045278
# hyperlipidemia                        0.139036         0.062782
# SelfPay_health_examination           -0.004093         0.010008
# health_examination                    1.000000         0.067800
# Colonscopy_past                       0.067800         1.000000
# outcome_screen                        0.117244         0.037815
#
#                             outcome_screen
# age_gp                            0.119103
# oc_gp                            -0.077423
# COUNTY_                           0.007205
# CCI_MI                           -0.001644
# CCI_CHF                           0.002193
# CCI_PVD                           0.007367
# CCI_CVD                           0.005838
# CCI_Dementia                      0.010228
# CCI_COPD                          0.029656
# CCI_Rheumatic                     0.005405
# CCI_Ulcer                         0.058055
# CCI_MLD                           0.083156
# CCI_DM_wo_chronic                 0.044628
# CCI_DM_w_chronic                  0.026146
# CCI_Hemiplegia                   -0.007129
# CCI_Renal                         0.013012
# CCI_Malignancy                    0.019412
# CCI_MSLD                          0.003887
# CCI_Cancer                       -0.002519
# CCI_AIDS                         -0.001016
# hypertension                      0.060602
# hyperlipidemia                    0.067923
# SelfPay_health_examination       -0.013649
# health_examination                0.117244
# Colonscopy_past                   0.037815
# outcome_screen                    1.000000
#
# [26 rows x 26 columns]

# %%
## numeric 
df_3y_M_Ty_num = df_3y_M_T.iloc[:, -4:-2]
df_3y_M_Ty_num['outcome_screen'] = df_3y_M_T.outcome_screen
df_3y_M_Ty_num.corr()
# Out:
#                 OPD_visit  IPD_visit  outcome_screen
# OPD_visit        1.000000   0.199831        0.106804
# IPD_visit        0.199831   1.000000        0.007617
# outcome_screen   0.106804   0.007617        1.000000

# %% [markdown]
# # Split to training/ valid/ test

# %%
X_train = df_3y_M_T[df_3y_M_T.year == 2017].iloc[:, :-2]
y_train = df_3y_M_T[df_3y_M_T.year == 2017].outcome_screen

X_valid = df_3y_M_T[df_3y_M_T.year == 2018].iloc[:, :-2]
y_valid = df_3y_M_T[df_3y_M_T.year == 2018].outcome_screen

X_test = df_3y_M_T[df_3y_M_T.year == 2019].iloc[:, :-2]
y_test = df_3y_M_T[df_3y_M_T.year == 2019].outcome_screen

# %% [markdown]
# # Model_XGBoost Classifier

# %%
start_time = time.time()

xgb = XGBClassifier()
cv = cross_val_score(xgb,X_train,y_train,cv=5)
print(xgboost.__version__)
print(cv)
print('XGBClassifier:', cv.mean())
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [15:17:21] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:17:21] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:17:21] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:17:22] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:17:22] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 1.4.2
# [0.75120989 0.75479477 0.75569098 0.75493008 0.75582646]
# XGBClassifier: 0.7544904375889431
# --- 1.4542200565338135 seconds ---

# %% [markdown]
# # Training

# %%
train = confusio_matrix(xgb, X_train, y_train)
plot_roc_curve(xgb, X_train, y_train)

train = train.rename(index={0: "M_T_HPA+CGRD_train"})
print('--------------- True/False Pos/Neg ---------------')
print(train, '\n')

train_imp = get_impotances(xgb, X_train, y_train)
train_imp.columns = ['M_T_HPA+CGRD_column', 'M_T_train_impor']

# train_imp
# Out:
# [15:17:22] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# --------------- True/False Pos/Neg ---------------
#                    True Neg False Pos False Neg True Pos   AUC
# M_T_HPA+CGRD_train    21013       206      5936      738  0.55
#
# [15:17:23] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# # Validation

# %%
valid = confusio_matrix(xgb, X_valid, y_valid)
plot_roc_curve(xgb, X_valid, y_valid)

valid = valid.rename(index={0: "M_T_HPA+CGRD_valid"})
print('--------------- True/False Pos/Neg ---------------')
print(valid, '\n')

valid_imp = get_impotances(xgb, X_valid, y_valid)
valid_imp.columns = ['M_T_HPA+CGRD_column', 'M_T_valid_impor']
# valid_imp
# Out:
# [15:17:23] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# --------------- True/False Pos/Neg ---------------
#                    True Neg False Pos False Neg True Pos    AUC
# M_T_HPA+CGRD_valid    20127       318      5683      953  0.564
#
# [15:17:24] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# # Test

# %%
test = confusio_matrix(xgb, X_test, y_test)
plot_roc_curve(xgb, X_test, y_test)

test = test.rename(index={0: "M_T_HPA+CGRD_test"})
print('--------------- True/False Pos/Neg ---------------')
print(test, '\n')

test_imp = get_impotances(xgb, X_test, y_test)
test_imp.columns = ['M_T_HPA+CGRD_column', 'M_T_test_impor']
# test_imp
# Out:
# [15:17:24] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# --------------- True/False Pos/Neg ---------------
#                   True Neg False Pos False Neg True Pos    AUC
# M_T_HPA+CGRD_test    20226       175      5472      701  0.552
#
# [15:17:25] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# # Result

# %%
print('--- Male_Taipei HPA+CGRD result---')
result = pd.concat([train, valid, test])
result
# Out:
# --- Male_Taipei HPA+CGRD result---
#                    True Neg False Pos False Neg True Pos    AUC
# M_T_HPA+CGRD_train    21013       206      5936      738   0.55
# M_T_HPA+CGRD_valid    20127       318      5683      953  0.564
# M_T_HPA+CGRD_test     20226       175      5472      701  0.552

# %%
result1 = train_imp.merge(valid_imp, left_on='M_T_HPA+CGRD_column', right_on='M_T_HPA+CGRD_column')
result1 = result1.merge(test_imp, left_on='M_T_HPA+CGRD_column', right_on='M_T_HPA+CGRD_column')
result1
# Out:
#            M_T_HPA+CGRD_column  M_T_train_impor  M_T_valid_impor  \
# 0                        oc_gp         0.079405         0.064624
# 1                      CCI_MLD         0.074481         0.062764
# 2           health_examination         0.072379         0.174050
# 3                       age_gp         0.069524         0.075749
# 4                    OPD_visit         0.058960         0.035917
# 5   SelfPay_health_examination         0.045643         0.027220
# 6            CCI_DM_wo_chronic         0.043303         0.033027
# 7                    CCI_Renal         0.041998         0.038446
# 8               hyperlipidemia         0.039758         0.030479
# 9                      CCI_CHF         0.039443         0.022531
# 10                     CCI_CVD         0.038606         0.036996
# 11             Colonscopy_past         0.036865         0.037567
# 12                hypertension         0.035684         0.028774
# 13                    CCI_COPD         0.035258         0.032373
# 14            CCI_DM_w_chronic         0.033692         0.034741
# 15                   CCI_Ulcer         0.033440         0.037581
# 16                     COUNTY_         0.032037         0.028446
# 17               CCI_Rheumatic         0.031681         0.021581
# 18                      CCI_MI         0.027109         0.025264
# 19              CCI_Malignancy         0.026954         0.036287
# 20                   IPD_visit         0.025794         0.025633
# 21                     CCI_PVD         0.023822         0.031809
# 22                    CCI_MSLD         0.023512         0.023350
# 23                CCI_Dementia         0.019801         0.014905
# 24              CCI_Hemiplegia         0.010853         0.011150
# 25                  CCI_Cancer         0.000000         0.000000
# 26                    CCI_AIDS         0.000000         0.008737
#
#     M_T_test_impor
# 0         0.065845
# 1         0.064511
# 2         0.125964
# 3         0.062157
# 4         0.038959
# 5         0.027730
# 6         0.035369
# 7         0.042355
# 8         0.037605
# 9         0.040429
# 10        0.045793
# 11        0.029809
# 12        0.032153
# 13        0.024153
# 14        0.041179
# 15        0.035299
# 16        0.035190
# 17        0.025156
# 18        0.032213
# 19        0.030849
# 20        0.036657
# 21        0.031802
# 22        0.013886
# 23        0.019598
# 24        0.016508
# 25        0.005586
# 26        0.003242
