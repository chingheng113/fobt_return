# %% [markdown]
# # Health Promotion Administration
# # & CGRD

# %%
import numpy as np
from utils import *

# %%
warnings.filterwarnings("ignore")  
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\for github'

# %% [markdown]
# # Read csv- CGRD

# %%
cgrd_2017 = pd.read_csv('data\\cgrd_2017.csv')
cgrd_2018 = pd.read_csv('data\\cgrd_2018.csv')
cgrd_2019 = pd.read_csv('data\\cgrd_2019.csv')

cgrd_2017.info()
cgrd_2018.info()
cgrd_2019.info()

cgrd_2017['year'] = 2017
cgrd_2018['year'] = 2018
cgrd_2019['year'] = 2019

cgrd_2017.tail(2)
cgrd_2018.tail(2)
cgrd_2019.tail(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268005 entries, 0 to 268004
# Columns: 114 entries, idcode to ICD_CODE
# dtypes: float64(20), int64(66), object(28)
# memory usage: 233.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271895 entries, 0 to 271894
# Columns: 114 entries, idcode to ICD_CODE
# dtypes: float64(20), int64(66), object(28)
# memory usage: 236.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274233 entries, 0 to 274232
# Columns: 114 entries, idcode to ICD_CODE
# dtypes: float64(17), int64(66), object(31)
# memory usage: 238.5+ MB
#                                           idcode breast  data_date  \
# 274231  FFFF83BC5D8EBA54B38CD37DDD2A6B1AC8311471    NaN     201912
# 274232  FFFFAFA8D6A70AF762326FF3E6EBF5C5AEC56324    NaN     201909
#
#               hosp BC_n  bc_gp        FOBT          OC  birth_year  age  ...  \
# 274231  1132070011    N    NaN         NaN  2017-08-08        1964   55  ...
# 274232  1101010012    0    6.0  2017-03-02         NaN        1962   57  ...
#
#         Colonscopy_past_date Colorectal_cancer  CLNCDXDAT CLNCDXDAT1  CAUSE  \
# 274231                   NaN                 0        NaN        NaN    NaN
# 274232                   NaN                 0        NaN        NaN    NaN
#
#         ICD  D_DATE CAUSE_CNM ICD_CODE  year
# 274231  NaN     NaN       NaN      NaN  2019
# 274232  NaN     NaN       NaN      NaN  2019
#
# [2 rows x 115 columns]

# %%
## concat 3 years
cgrd_3y = pd.concat([cgrd_2017, cgrd_2018, cgrd_2019]).reset_index(drop=True)
cgrd_3y.tail(2)
# Out:
#                                           idcode breast  data_date  \
# 814131  FFFF83BC5D8EBA54B38CD37DDD2A6B1AC8311471    NaN     201912
# 814132  FFFFAFA8D6A70AF762326FF3E6EBF5C5AEC56324    NaN     201909
#
#               hosp BC_n  bc_gp        FOBT          OC  birth_year  age  ...  \
# 814131  1132070011    N    NaN         NaN  2017-08-08        1964   55  ...
# 814132  1101010012    0    6.0  2017-03-02         NaN        1962   57  ...
#
#         Colonscopy_past_date Colorectal_cancer  CLNCDXDAT CLNCDXDAT1  CAUSE  \
# 814131                   NaN                 0        NaN        NaN    NaN
# 814132                   NaN                 0        NaN        NaN    NaN
#
#         ICD  D_DATE CAUSE_CNM ICD_CODE  year
# 814131  NaN     NaN       NaN      NaN  2019
# 814132  NaN     NaN       NaN      NaN  2019
#
# [2 rows x 115 columns]

# %% [markdown]
# # Select columns

# %%
df_3y = pd.DataFrame()
df_3y['hosp'] = (cgrd_3y.hosp).map({1101010012:'Taipei', 1132070011:'Linkou'})
df_3y['bc_gp'] = (cgrd_3y.bc_gp)
df_3y['age_gp'] = (cgrd_3y.age_gp)
df_3y['oc_gp'] = (cgrd_3y.oc_gp)
df_3y['pas_gp'] = (cgrd_3y.pas_gp)
df_3y['sex'] = (cgrd_3y.sex)
df_3y['COUNTY_'] = (cgrd_3y.COUNTY_)
# df_3y['hosp_shopping_logistic'] = (cgrd_3y.hosp_shopping_logistic)
df_3y['CCI_MI'] = (cgrd_3y.CCI_MI)
df_3y['CCI_CHF'] = (cgrd_3y.CCI_CHF)

df_3y['CCI_PVD'] = (cgrd_3y.CCI_PVD)
df_3y['CCI_CVD'] = (cgrd_3y.CCI_CVD)
df_3y['CCI_Dementia'] = (cgrd_3y.CCI_Dementia)
df_3y['CCI_COPD'] = (cgrd_3y.CCI_COPD)
df_3y['CCI_Rheumatic'] = (cgrd_3y.CCI_Rheumatic)
df_3y['CCI_Ulcer'] = (cgrd_3y.CCI_Ulcer)
df_3y['CCI_MLD'] = (cgrd_3y.CCI_MLD)
df_3y['CCI_DM_wo_chronic'] = (cgrd_3y.CCI_DM_wo_chronic)
df_3y['CCI_DM_w_chronic'] = (cgrd_3y.CCI_DM_w_chronic)
df_3y['CCI_Hemiplegia'] = (cgrd_3y.CCI_Hemiplegia)

df_3y['CCI_Renal'] = (cgrd_3y.CCI_Renal)
df_3y['CCI_Malignancy'] = (cgrd_3y.CCI_Malignancy)
df_3y['CCI_MSLD'] = (cgrd_3y.CCI_MSLD)
df_3y['CCI_Cancer'] = (cgrd_3y.CCI_Cancer)
df_3y['CCI_AIDS'] = (cgrd_3y.CCI_AIDS)
df_3y['hypertension'] = (cgrd_3y.hypertension)
df_3y['hyperlipidemia'] = (cgrd_3y.hyperlipidemia)
# df_3y['Hba1c'] = (cgrd_3y.Hba1c)
# df_3y['cholesterol'] = (cgrd_3y.cholesterol)
# df_3y['triglyceride'] = (cgrd_3y.triglyceride)

# df_3y['HDL'] = (cgrd_3y.HDL)
df_3y['SelfPay_health_examination'] = (cgrd_3y.SelfPay_health_examination)
df_3y['health_examination'] = (cgrd_3y.health_examination)
# df_3y['health_examination_diff'] = (cgrd_3y.health_examination_diff)
df_3y['Colonscopy_past'] = (cgrd_3y.Colonscopy_past)
df_3y['OPD_visit'] = (cgrd_3y.OPD_visit)

df_3y['IPD_visit'] = (cgrd_3y.IPD_visit)
df_3y['year'] = (cgrd_3y.year)
df_3y['outcome_screen'] = (cgrd_3y.outcome_screen)

df_3y.tail(2)
# Out:
#           hosp  bc_gp  age_gp  oc_gp  pas_gp sex  COUNTY_  CCI_MI  CCI_CHF  \
# 814131  Linkou    NaN       2      1     NaN   M        1       0        0
# 814132  Taipei    6.0       2      9     4.0   F        1       0        0
#
#         CCI_PVD  ...  CCI_AIDS  hypertension  hyperlipidemia  \
# 814131        0  ...         0             0               0
# 814132        0  ...         0             0               0
#
#         SelfPay_health_examination  health_examination  Colonscopy_past  \
# 814131                           0                   0                0
# 814132                           0                   0                0
#
#         OPD_visit  IPD_visit  year  outcome_screen
# 814131          2          0  2019               0
# 814132          0          0  2019               0
#
# [2 rows x 33 columns]

# %% [markdown]
# # Split on sex

# %%
# ## male
# df_3y_M =  df_3y[(df_3y.sex == 'M') & (df_3y.hosp == 'Taipei')].reset_index(drop=True)
# del df_3y_M['sex']
# del df_3y_M['bc_gp']
# del df_3y_M['pas_gp']
# del df_3y_F_T['hosp']

# df_3y_M.info()

# %%
## female
df_3y_F_T = df_3y[(df_3y.sex == 'F') & (df_3y.hosp == 'Taipei')].reset_index(drop=True)
del df_3y_F_T['sex']
del df_3y_F_T['hosp']

df_3y_F_T.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129170 entries, 0 to 129169
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   bc_gp                       129170 non-null  float64
#  1   age_gp                      129170 non-null  int64
#  2   oc_gp                       129170 non-null  int64
#  3   pas_gp                      129170 non-null  float64
#  4   COUNTY_                     129170 non-null  int64
#  5   CCI_MI                      129170 non-null  int64
#  6   CCI_CHF                     129170 non-null  int64
#  7   CCI_PVD                     129170 non-null  int64
#  8   CCI_CVD                     129170 non-null  int64
#  9   CCI_Dementia                129170 non-null  int64
#  10  CCI_COPD                    129170 non-null  int64
#  11  CCI_Rheumatic               129170 non-null  int64
#  12  CCI_Ulcer                   129170 non-null  int64
#  13  CCI_MLD                     129170 non-null  int64
#  14  CCI_DM_wo_chronic           129170 non-null  int64
#  15  CCI_DM_w_chronic            129170 non-null  int64
#  16  CCI_Hemiplegia              129170 non-null  int64
#  17  CCI_Renal                   129170 non-null  int64
#  18  CCI_Malignancy              129170 non-null  int64
#  19  CCI_MSLD                    129170 non-null  int64
#  20  CCI_Cancer                  129170 non-null  int64
#  21  CCI_AIDS                    129170 non-null  int64
#  22  hypertension                129170 non-null  int64
#  23  hyperlipidemia              129170 non-null  int64
#  24  SelfPay_health_examination  129170 non-null  int64
#  25  health_examination          129170 non-null  int64
#  26  Colonscopy_past             129170 non-null  int64
#  27  OPD_visit                   129170 non-null  int64
#  28  IPD_visit                   129170 non-null  int64
#  29  year                        129170 non-null  int64
#  30  outcome_screen              129170 non-null  int64
# dtypes: float64(2), int64(29)
# memory usage: 30.6 MB

# %% [markdown]
# # Correlation

# %%
## category
df_3y_F_Ty_catg = df_3y_F_T.iloc[:, :-4]
df_3y_F_Ty_catg['outcome_screen'] = df_3y_F_T.outcome_screen

df_3y_F_Ty_catg.corr(method='spearman') ## CCI_AIDS.value_counts() only 0 withou 1
# Out:
#                                bc_gp    age_gp     oc_gp    pas_gp   COUNTY_  \
# bc_gp                       1.000000  0.275853  0.081588  0.416398  0.003207
# age_gp                      0.275853  1.000000 -0.024333  0.123472 -0.010967
# oc_gp                       0.081588 -0.024333  1.000000  0.104731  0.011227
# pas_gp                      0.416398  0.123472  0.104731  1.000000  0.002663
# COUNTY_                     0.003207 -0.010967  0.011227  0.002663  1.000000
# CCI_MI                      0.008267  0.018896  0.006308  0.008277  0.003390
# CCI_CHF                     0.017524  0.031981 -0.005466  0.005621 -0.003313
# CCI_PVD                     0.015239  0.022474  0.005895  0.009020  0.000654
# CCI_CVD                     0.041682  0.061334  0.004742  0.025104  0.004373
# CCI_Dementia                0.037126  0.055845 -0.005688  0.014573 -0.001454
# CCI_COPD                    0.011866  0.041937 -0.006963  0.007367  0.010644
# CCI_Rheumatic               0.010683  0.006428  0.003136  0.019487 -0.001189
# CCI_Ulcer                  -0.010760  0.039168 -0.001980 -0.020448  0.010555
# CCI_MLD                    -0.035159  0.027121  0.002105 -0.021279  0.014834
# CCI_DM_wo_chronic           0.053443  0.125202  0.006730  0.044520  0.015316
# CCI_DM_w_chronic            0.039558  0.074134 -0.002139  0.028386  0.007952
# CCI_Hemiplegia              0.013110  0.010420  0.001009  0.012571  0.001867
# CCI_Renal                   0.023708  0.036869  0.010407  0.022919  0.002722
# CCI_Malignancy              0.039220  0.014083  0.006792 -0.028023 -0.009591
# CCI_MSLD                    0.000731  0.004030 -0.000802 -0.000729 -0.000451
# CCI_Cancer                  0.007771  0.001438 -0.002055  0.004953 -0.001884
# CCI_AIDS                         NaN       NaN       NaN       NaN       NaN
# hypertension                0.079707  0.157109  0.020640  0.062456  0.022069
# hyperlipidemia              0.028143  0.136415  0.014110  0.024734  0.029707
# SelfPay_health_examination -0.005125 -0.006369  0.003834 -0.019178  0.001268
# health_examination         -0.002518  0.090904 -0.013985 -0.039197  0.016269
# Colonscopy_past            -0.057282  0.023239 -0.000783 -0.070514  0.012730
# outcome_screen             -0.199104  0.054758 -0.084276 -0.224860 -0.003002
#
#                               CCI_MI   CCI_CHF   CCI_PVD   CCI_CVD  \
# bc_gp                       0.008267  0.017524  0.015239  0.041682
# age_gp                      0.018896  0.031981  0.022474  0.061334
# oc_gp                       0.006308 -0.005466  0.005895  0.004742
# pas_gp                      0.008277  0.005621  0.009020  0.025104
# COUNTY_                     0.003390 -0.003313  0.000654  0.004373
# CCI_MI                      1.000000  0.076196  0.031531  0.015066
# CCI_CHF                     0.076196  1.000000  0.066930  0.021381
# CCI_PVD                     0.031531  0.066930  1.000000  0.024033
# CCI_CVD                     0.015066  0.021381  0.024033  1.000000
# CCI_Dementia                0.010069  0.000118  0.014104  0.070281
# CCI_COPD                   -0.003105  0.024137  0.003382  0.009720
# CCI_Rheumatic              -0.002601  0.008303  0.026752  0.006371
# CCI_Ulcer                   0.008341  0.014759  0.010187  0.039221
# CCI_MLD                    -0.001115  0.017568  0.011636  0.007736
# CCI_DM_wo_chronic           0.028786  0.055112  0.049725  0.082261
# CCI_DM_w_chronic            0.027092  0.022969  0.043045  0.048177
# CCI_Hemiplegia             -0.000530 -0.001065  0.007502  0.134366
# CCI_Renal                   0.014649  0.043624  0.084873  0.022750
# CCI_Malignancy             -0.001794  0.005627  0.012323  0.004463
# CCI_MSLD                   -0.000261 -0.000524 -0.000453 -0.001071
# CCI_Cancer                 -0.000542 -0.001089 -0.000942 -0.002225
# CCI_AIDS                         NaN       NaN       NaN       NaN
# hypertension                0.031608  0.092273  0.078316  0.178046
# hyperlipidemia              0.047152  0.051341  0.065256  0.120047
# SelfPay_health_examination -0.000730  0.009128  0.004854 -0.000383
# health_examination          0.019203  0.039207  0.039645  0.070800
# Colonscopy_past             0.003056  0.006025  0.008035  0.014742
# outcome_screen              0.002196 -0.001685  0.003254 -0.000715
#
#                             CCI_Dementia  ...  CCI_Malignancy  CCI_MSLD  \
# bc_gp                           0.037126  ...        0.039220  0.000731
# age_gp                          0.055845  ...        0.014083  0.004030
# oc_gp                          -0.005688  ...        0.006792 -0.000802
# pas_gp                          0.014573  ...       -0.028023 -0.000729
# COUNTY_                        -0.001454  ...       -0.009591 -0.000451
# CCI_MI                          0.010069  ...       -0.001794 -0.000261
# CCI_CHF                         0.000118  ...        0.005627 -0.000524
# CCI_PVD                         0.014104  ...        0.012323 -0.000453
# CCI_CVD                         0.070281  ...        0.004463 -0.001071
# CCI_Dementia                    1.000000  ...       -0.003681 -0.000646
# CCI_COPD                        0.000554  ...        0.011291  0.009217
# CCI_Rheumatic                  -0.000321  ...       -0.001031  0.017811
# CCI_Ulcer                       0.014210  ...        0.041878  0.020917
# CCI_MLD                         0.004248  ...        0.054681  0.043991
# CCI_DM_wo_chronic               0.035379  ...        0.031347  0.013088
# CCI_DM_w_chronic                0.002061  ...        0.009619 -0.001134
# CCI_Hemiplegia                  0.040177  ...       -0.001578 -0.000252
# CCI_Renal                       0.008746  ...        0.015217 -0.000895
# CCI_Malignancy                 -0.003681  ...        1.000000  0.011204
# CCI_MSLD                       -0.000646  ...        0.011204  1.000000
# CCI_Cancer                     -0.001341  ...        0.132216 -0.000257
# CCI_AIDS                             NaN  ...             NaN       NaN
# hypertension                    0.042750  ...        0.032969  0.001534
# hyperlipidemia                  0.024951  ...        0.047296  0.014424
# SelfPay_health_examination     -0.001805  ...       -0.005118 -0.000346
# health_examination              0.037213  ...        0.083914  0.013259
# Colonscopy_past                 0.003307  ...        0.038327  0.001019
# outcome_screen                 -0.005963  ...        0.006290  0.000759
#
#                             CCI_Cancer  CCI_AIDS  hypertension  \
# bc_gp                         0.007771       NaN      0.079707
# age_gp                        0.001438       NaN      0.157109
# oc_gp                        -0.002055       NaN      0.020640
# pas_gp                        0.004953       NaN      0.062456
# COUNTY_                      -0.001884       NaN      0.022069
# CCI_MI                       -0.000542       NaN      0.031608
# CCI_CHF                      -0.001089       NaN      0.092273
# CCI_PVD                      -0.000942       NaN      0.078316
# CCI_CVD                      -0.002225       NaN      0.178046
# CCI_Dementia                 -0.001341       NaN      0.042750
# CCI_COPD                     -0.000487       NaN      0.073061
# CCI_Rheumatic                 0.006609       NaN      0.041388
# CCI_Ulcer                     0.001199       NaN      0.083001
# CCI_MLD                       0.011004       NaN      0.084913
# CCI_DM_wo_chronic             0.002152       NaN      0.381189
# CCI_DM_w_chronic             -0.002355       NaN      0.195615
# CCI_Hemiplegia               -0.000523       NaN      0.027209
# CCI_Renal                     0.006527       NaN      0.145731
# CCI_Malignancy                0.132216       NaN      0.032969
# CCI_MSLD                     -0.000257       NaN      0.001534
# CCI_Cancer                    1.000000       NaN      0.013178
# CCI_AIDS                           NaN       NaN           NaN
# hypertension                  0.013178       NaN      1.000000
# hyperlipidemia               -0.002398       NaN      0.469143
# SelfPay_health_examination   -0.000720       NaN      0.003735
# health_examination            0.032229       NaN      0.148802
# Colonscopy_past               0.001606       NaN      0.038155
# outcome_screen               -0.002566       NaN      0.000689
#
#                             hyperlipidemia  SelfPay_health_examination  \
# bc_gp                             0.028143                   -0.005125
# age_gp                            0.136415                   -0.006369
# oc_gp                             0.014110                    0.003834
# pas_gp                            0.024734                   -0.019178
# COUNTY_                           0.029707                    0.001268
# CCI_MI                            0.047152                   -0.000730
# CCI_CHF                           0.051341                    0.009128
# CCI_PVD                           0.065256                    0.004854
# CCI_CVD                           0.120047                   -0.000383
# CCI_Dementia                      0.024951                   -0.001805
# CCI_COPD                          0.057289                    0.005445
# CCI_Rheumatic                     0.017460                   -0.003452
# CCI_Ulcer                         0.121077                   -0.000355
# CCI_MLD                           0.201731                    0.001545
# CCI_DM_wo_chronic                 0.441847                    0.007324
# CCI_DM_w_chronic                  0.194996                   -0.003171
# CCI_Hemiplegia                    0.016964                   -0.000704
# CCI_Renal                         0.079159                   -0.002503
# CCI_Malignancy                    0.047296                   -0.005118
# CCI_MSLD                          0.014424                   -0.000346
# CCI_Cancer                       -0.002398                   -0.000720
# CCI_AIDS                               NaN                         NaN
# hypertension                      0.469143                    0.003735
# hyperlipidemia                    1.000000                    0.010581
# SelfPay_health_examination        0.010581                    1.000000
# health_examination                0.161097                    0.003384
# Colonscopy_past                   0.067676                    0.001862
# outcome_screen                    0.032824                   -0.012302
#
#                             health_examination  Colonscopy_past  \
# bc_gp                                -0.002518        -0.057282
# age_gp                                0.090904         0.023239
# oc_gp                                -0.013985        -0.000783
# pas_gp                               -0.039197        -0.070514
# COUNTY_                               0.016269         0.012730
# CCI_MI                                0.019203         0.003056
# CCI_CHF                               0.039207         0.006025
# CCI_PVD                               0.039645         0.008035
# CCI_CVD                               0.070800         0.014742
# CCI_Dementia                          0.037213         0.003307
# CCI_COPD                              0.077618         0.024305
# CCI_Rheumatic                         0.089939         0.008389
# CCI_Ulcer                             0.125694         0.119406
# CCI_MLD                               0.093429         0.094012
# CCI_DM_wo_chronic                     0.126377         0.029874
# CCI_DM_w_chronic                      0.071331         0.016110
# CCI_Hemiplegia                        0.015212         0.000187
# CCI_Renal                             0.081331         0.015476
# CCI_Malignancy                        0.083914         0.038327
# CCI_MSLD                              0.013259         0.001019
# CCI_Cancer                            0.032229         0.001606
# CCI_AIDS                                   NaN              NaN
# hypertension                          0.148802         0.038155
# hyperlipidemia                        0.161097         0.067676
# SelfPay_health_examination            0.003384         0.001862
# health_examination                    1.000000         0.057839
# Colonscopy_past                       0.057839         1.000000
# outcome_screen                        0.082173         0.030860
#
#                             outcome_screen
# bc_gp                            -0.199104
# age_gp                            0.054758
# oc_gp                            -0.084276
# pas_gp                           -0.224860
# COUNTY_                          -0.003002
# CCI_MI                            0.002196
# CCI_CHF                          -0.001685
# CCI_PVD                           0.003254
# CCI_CVD                          -0.000715
# CCI_Dementia                     -0.005963
# CCI_COPD                          0.015823
# CCI_Rheumatic                     0.001655
# CCI_Ulcer                         0.036017
# CCI_MLD                           0.051174
# CCI_DM_wo_chronic                 0.005372
# CCI_DM_w_chronic                 -0.002044
# CCI_Hemiplegia                   -0.001980
# CCI_Renal                        -0.001058
# CCI_Malignancy                    0.006290
# CCI_MSLD                          0.000759
# CCI_Cancer                       -0.002566
# CCI_AIDS                               NaN
# hypertension                      0.000689
# hyperlipidemia                    0.032824
# SelfPay_health_examination       -0.012302
# health_examination                0.082173
# Colonscopy_past                   0.030860
# outcome_screen                    1.000000
#
# [28 rows x 28 columns]

# %%
## numeric 
df_3y_F_Ty_num = df_3y_F_T.iloc[:, -4:-2]
df_3y_F_Ty_num['outcome_screen'] = df_3y_F_T.outcome_screen
df_3y_F_Ty_num.corr()
# Out:
#                 OPD_visit  IPD_visit  outcome_screen
# OPD_visit        1.000000   0.183223        0.061068
# IPD_visit        0.183223   1.000000        0.001272
# outcome_screen   0.061068   0.001272        1.000000

# %% [markdown]
# # Split to training/ valid/ test

# %%
X_train = df_3y_F_T[df_3y_F_T.year == 2017].iloc[:, :-2]
y_train = df_3y_F_T[df_3y_F_T.year == 2017].outcome_screen

X_valid = df_3y_F_T[df_3y_F_T.year == 2018].iloc[:, :-2]
y_valid = df_3y_F_T[df_3y_F_T.year == 2018].outcome_screen

X_test = df_3y_F_T[df_3y_F_T.year == 2019].iloc[:, :-2]
y_test = df_3y_F_T[df_3y_F_T.year == 2019].outcome_screen

# %% [markdown]
# # Model_XGBoost Classifier

# %%
start_time = time.time()

xgb = XGBClassifier()
cv = cross_val_score(xgb,X_train,y_train,cv=5)
print(xgboost.__version__)
print(cv)
print('XGBClassifier:', cv.mean())
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [15:46:23] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:46:24] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:46:24] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:46:25] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:46:25] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 1.4.2
# [0.74583619 0.74480949 0.7452658  0.74686288 0.74067313]
# XGBClassifier: 0.744689497447679
# --- 2.2435402870178223 seconds ---

# %% [markdown]
# # Training

# %%
train = confusio_matrix(xgb, X_train, y_train)
plot_roc_curve(xgb, X_train, y_train)

train = train.rename(index={0: "F_T_+HPA_train"})
print('--------------- True/False Pos/Neg ---------------')
print(train, '\n')

train_imp = get_impotances(xgb, X_train, y_train)
train_imp.columns = ['F_T_+HPA_column', 'F_T_train_impor']

# train_imp
# Out:
# [15:46:25] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# --------------- True/False Pos/Neg ---------------
#                True Neg False Pos False Neg True Pos    AUC
# F_T_+HPA_train    29441      2046      8140     4202  0.638
#
# [15:46:26] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# # Validation

# %%
valid = confusio_matrix(xgb, X_valid, y_valid)
plot_roc_curve(xgb, X_valid, y_valid)

valid = valid.rename(index={0: "F_T_+HPA_valid"})
print('--------------- True/False Pos/Neg ---------------')
print(valid, '\n')

valid_imp = get_impotances(xgb, X_valid, y_valid)
valid_imp.columns = ['F_T_+HPA_column', 'F_T_valid_impor']
# valid_imp
# Out:
# [15:46:27] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# --------------- True/False Pos/Neg ---------------
#                True Neg False Pos False Neg True Pos    AUC
# F_T_+HPA_valid    28184      2461      7487     4967  0.659
#
# [15:46:28] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# # Test

# %%
test = confusio_matrix(xgb, X_test, y_test)
plot_roc_curve(xgb, X_test, y_test)

test = test.rename(index={0: "F_T_+HPA_test"})
print('--------------- True/False Pos/Neg ---------------')
print(test, '\n')

test_imp = get_impotances(xgb, X_test, y_test)
test_imp.columns = ['F_T_+HPA_column', 'F_T_test_impor']
# test_imp
# Out:
# [15:46:28] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# --------------- True/False Pos/Neg ---------------
#               True Neg False Pos False Neg True Pos    AUC
# F_T_+HPA_test    28418      2217      7208     4399  0.653
#
# [15:46:29] WARNING: D:\Build\xgboost\xgboost-1.4.2.git\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# # Result

# %%
print('--- Female_Taipei +HPA result---')
result = pd.concat([train, valid, test])
result
# Out:
# --- Female_Taipei +HPA result---
#                True Neg False Pos False Neg True Pos    AUC
# F_T_+HPA_train    29441      2046      8140     4202  0.638
# F_T_+HPA_valid    28184      2461      7487     4967  0.659
# F_T_+HPA_test     28418      2217      7208     4399  0.653

# %%
result1 = train_imp.merge(valid_imp, left_on='F_T_+HPA_column', right_on='F_T_+HPA_column')
result1 = result1.merge(test_imp, left_on='F_T_+HPA_column', right_on='F_T_+HPA_column')
result1
# Out:
#                F_T_+HPA_column  F_T_train_impor  F_T_valid_impor  \
# 0                        bc_gp         0.348202         0.384987
# 1                       pas_gp         0.088048         0.090135
# 2           health_examination         0.053042         0.048230
# 3                       age_gp         0.051222         0.047179
# 4                        oc_gp         0.045249         0.034226
# 5              Colonscopy_past         0.027549         0.021919
# 6                      CCI_MLD         0.026923         0.028283
# 7                      COUNTY_         0.026300         0.021085
# 8               CCI_Malignancy         0.025597         0.028659
# 9                    OPD_visit         0.025295         0.022625
# 10  SelfPay_health_examination         0.023550         0.017755
# 11                    CCI_COPD         0.022599         0.020982
# 12               CCI_Rheumatic         0.021247         0.017979
# 13              hyperlipidemia         0.020412         0.027051
# 14                   CCI_Ulcer         0.020150         0.021791
# 15                hypertension         0.019964         0.018364
# 16            CCI_DM_w_chronic         0.019825         0.021752
# 17           CCI_DM_wo_chronic         0.018751         0.017633
# 18                   CCI_Renal         0.018572         0.014171
# 19                   IPD_visit         0.018344         0.016374
# 20                CCI_Dementia         0.016792         0.016344
# 21                     CCI_CVD         0.014248         0.023848
# 22                     CCI_PVD         0.013891         0.006811
# 23                     CCI_CHF         0.013329         0.009082
# 24                      CCI_MI         0.007663         0.006227
# 25              CCI_Hemiplegia         0.006532         0.005995
# 26                  CCI_Cancer         0.004110         0.010514
# 27                    CCI_MSLD         0.002595         0.000000
# 28                    CCI_AIDS         0.000000         0.000000
#
#     F_T_test_impor
# 0         0.368053
# 1         0.101609
# 2         0.040139
# 3         0.038402
# 4         0.029927
# 5         0.021653
# 6         0.028700
# 7         0.022370
# 8         0.026633
# 9         0.026496
# 10        0.035387
# 11        0.020429
# 12        0.021110
# 13        0.020517
# 14        0.022961
# 15        0.022097
# 16        0.017455
# 17        0.024409
# 18        0.014591
# 19        0.015116
# 20        0.020153
# 21        0.016337
# 22        0.010773
# 23        0.014705
# 24        0.008981
# 25        0.003463
# 26        0.007534
# 27        0.000000
# 28        0.000000
